# %%
# %matplotlib inline 
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from testy import *

# %autoreload 2
act_dict,u,pers_l,pers_dict,pact,lact=create_dict_of_acts('corpora/HamletShakespeare.txt')

graph_dic,ract_dic,pernode_dict,nodper_dic=create_graph_dict(act_dict,pers_l,pers_dict,u)
for k,v in graph_dic.items():
    print k,nx.info(v)
# Out:
# False
# I Name:
# Type: Graph
# Number of nodes: 13
# Number of edges: 23
# Average degree:   3.5385
# II Name:
# Type: Graph
# Number of nodes: 10
# Number of edges: 15
# Average degree:   3.0000
# IV Name:
# Type: Graph
# Number of nodes: 14
# Number of edges: 18
# Average degree:   2.5714
# III Name:
# Type: Graph
# Number of nodes: 7
# Number of edges: 10
# Average degree:   2.8571
# V Name:
# Type: Graph
# Number of nodes: 11
# Number of edges: 17
# Average degree:   3.0909

# %%
from syntheticThreeLayerGraph_time import synthetic_multi_level_dict,plot_graph_dict,plot_graph_k_n

# %%
G, list_of_Graphs_final, Gagr, edgeList ,nmap ,mapping,k,n=synthetic_multi_level_dict(graph_dic,pernode_dict,nodper_dic,ract_dic,No_isolates=True)

# %%
created_pos=plot_graph_dict(G,n,k,list_of_Graphs_final, Gagr,d1=0.8,d2=5.0,nodesize=1000,withlabels=False,edgelist=edgeList,layout=True,b_alpha=0.5)

# %%
created_pos,fig=plot_graph_k_n(k,n,G,list_of_Graphs_final, Gagr,d1=5,d2=4,d3=2,d4=2,d5=2,d6=15,d7=0,d8=1,d9=5,colors_grey='gray',nodesize=1000,withlabels=False,edgelist=edgeList,layout=False,b_alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-b3c7e1a84e24> in <module>()
# ----> 1 created_pos,fig=plot_graph_k_n(k,n,G,list_of_Graphs_final, Gagr,d1=5,d2=4,d3=2,d4=2,d5=2,d6=15,d7=0,d8=1,d9=5,colors_grey='gray',nodesize=1000,withlabels=False,edgelist=edgeList,layout=False,b_alpha=0.8)
#
# /Users/mosesboudourides/Dropbox/python projects/LiteratureNetworks/syntheticThreeLayerGraph_time.pyc in plot_graph_k_n(k, n, G, list_of_Graphs_final, Gagr, d1, d2, d3, d4, d5, d6, d7, d8, d9, colors_grey, nodesize, withlabels, edgelist, layout, b_alpha)
#     555         pos=nx.spring_layout(Gagr)
#     556     else:
# --> 557         pos=nx.graphviz_layout(Gagr)
#     558         # pos=nx.random_layout(Gagr)
#     559
#
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/networkx/drawing/nx_pydot.pyc in graphviz_layout(G, prog, root, **kwds)
# ...
